# %% [markdown]
# _____
# ### Exercise 1

# %% [markdown]
# 1. Open the CSV file.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/joanby/python-ml-course/master/datasets/titanic/titanic3.csv')
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# _____
# 2. Get the names of all the columns, then iterate that object and print the following row by row: "Null values in Survived: 10" where 10 is the total of null or missing values in the Survived column.

# %%
column = df.columns.values

for i in column:    
    total_null = df[i].isnull().sum()
    print(f'Null values in {i}: {total_null}')
# Out:
# Null values in pclass: 0
# Null values in survived: 0
# Null values in name: 0
# Null values in sex: 0
# Null values in age: 263
# Null values in sibsp: 0
# Null values in parch: 0
# Null values in ticket: 0
# Null values in fare: 1
# Null values in cabin: 1014
# Null values in embarked: 2
# Null values in boat: 823
# Null values in body: 1188
# Null values in home.dest: 564

# %% [markdown]
# _____
# 3.Find out what the average age was and print "The average age was: mean"

# %%
age_mean = round(df['age'].mean(), 2) 
print(f'The average age was: {age_mean}')
# Out:
# The average age was: 29.88

# %% [markdown]
# _____
# 4. Create a table with the number of survivors divided by sex.

# %%
survivors = df.pivot_table(index='sex', aggfunc={'survived': sum})
survivors
# Out:
#         survived
# sex
# female       339
# male         161

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# _____
# 1. Open the CSV file

# %%
df_2 = pd.read_csv('opsd_germany_daily.csv')
df_2
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %% [markdown]
# _____
# 2. Fill with 0 the missing values in Wind and Solar

# %%
df_2.Wind.fillna(0, inplace=True)
df_2['Solar'].fillna(0, inplace=True)
df_2
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400    0.000   0.000         NaN
# 1     2006-01-02   1380.52100    0.000   0.000         NaN
# 2     2006-01-03   1442.53300    0.000   0.000         NaN
# 3     2006-01-04   1457.21700    0.000   0.000         NaN
# 4     2006-01-05   1477.13100    0.000   0.000         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %% [markdown]
# 3) La columna de Wind+Solar debe coincidir con la suma de Wind y Solar

# %%
df_2.eval('`Wind+Solar`= Wind + Solar', inplace=True) 
df_2
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar  \
# 0     2006-01-01   1069.18400    0.000   0.000         NaN
# 1     2006-01-02   1380.52100    0.000   0.000         NaN
# 2     2006-01-03   1442.53300    0.000   0.000         NaN
# 3     2006-01-04   1457.21700    0.000   0.000         NaN
# 4     2006-01-05   1477.13100    0.000   0.000         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
#       BACKTICK_QUOTED_STRING_Wind_PLUS_Solar
# 0                                      0.000
# 1                                      0.000
# 2                                      0.000
# 3                                      0.000
# ...

# %%
df_2.drop('Wind+Solar', axis=1, inplace=True) 
df_2
# Out:
#             Date  Consumption     Wind   Solar  \
# 0     2006-01-01   1069.18400    0.000   0.000
# 1     2006-01-02   1380.52100    0.000   0.000
# 2     2006-01-03   1442.53300    0.000   0.000
# 3     2006-01-04   1457.21700    0.000   0.000
# 4     2006-01-05   1477.13100    0.000   0.000
# ...          ...          ...      ...     ...
# 4378  2017-12-27   1263.94091  394.507  16.530
# 4379  2017-12-28   1299.86398  506.424  14.162
# 4380  2017-12-29   1295.08753  584.277  29.854
# 4381  2017-12-30   1215.44897  721.247   7.467
# 4382  2017-12-31   1107.11488  721.176  19.980
#
#       BACKTICK_QUOTED_STRING_Wind_PLUS_Solar
# 0                                      0.000
# 1                                      0.000
# 2                                      0.000
# 3                                      0.000
# 4                                      0.000
# ...                                      ...
# 4378                                 411.037
# ...

# %%
df_2.rename(columns={'BACKTICK_QUOTED_STRING_Wind_PLUS_Solar':'Wind+Solar'}, inplace=True)
df_2
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400    0.000   0.000       0.000
# 1     2006-01-02   1380.52100    0.000   0.000       0.000
# 2     2006-01-03   1442.53300    0.000   0.000       0.000
# 3     2006-01-04   1457.21700    0.000   0.000       0.000
# 4     2006-01-05   1477.13100    0.000   0.000       0.000
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %% [markdown]
# _____
# 4. Create a pivot table that displays Wind + Solar consumption according to date, it must be vertical.

# %%
# check if there are null values
df_2.Consumption.isnull().sum()
# Out:
# 0

# %%
table = df_2.pivot_table('Consumption', index='Date')
table
# Out:
#             Consumption
# Date
# 2006-01-01   1069.18400
# 2006-01-02   1380.52100
# 2006-01-03   1442.53300
# 2006-01-04   1457.21700
# 2006-01-05   1477.13100
# ...                 ...
# 2017-12-27   1263.94091
# 2017-12-28   1299.86398
# 2017-12-29   1295.08753
# 2017-12-30   1215.44897
# 2017-12-31   1107.11488
#
# [4383 rows x 1 columns]

# %% [markdown]
# _____
# 5. Replace the missing values ​​of the pivot table with the mean.

# %%
table.fillna(df_2.Consumption.mean(), inplace=True)

# %% [markdown]
# _____
# 6. View the statistical data of the CSV in general.

# %%
df_2.describe()
# Out:
#        Consumption         Wind        Solar   Wind+Solar
# count  4383.000000  4383.000000  4383.000000  4383.000000
# mean   1338.675836   109.800909    44.558071   154.358980
# std     165.775710   140.698109    60.853561   165.174461
# min     842.395000     0.000000     0.000000     0.000000
# 25%    1217.859000     0.000000     0.000000     0.000000
# 50%    1367.123000    62.293000     0.000000   123.808000
# 75%    1457.761000   162.366000    86.268000   248.019500
# max    1709.568000   826.278000   241.580000   851.556000

# %% [markdown]
# ____
# 7. Visualize the statistical data of the pivot table.

# %%
table.describe()
# Out:
#        Consumption
# count  4383.000000
# mean   1338.675836
# std     165.775710
# min     842.395000
# 25%    1217.859000
# 50%    1367.123000
# 75%    1457.761000
# max    1709.568000

# %% [markdown]
# _____
# 8. Create 3 arrays: solar energy, wind energy and consumption.

# %%
solar_e = np.array(df_2.Solar)
wind_e = np.array(df_2.Wind)
consumption = np.array(df_2.Consumption)

# %%
solar_e
# Out:
# array([ 0.   ,  0.   ,  0.   , ..., 29.854,  7.467, 19.98 ])

# %%
wind_e
# Out:
# array([  0.   ,   0.   ,   0.   , ..., 584.277, 721.247, 721.176])

# %%
consumption
# Out:
# array([1069.184  , 1380.521  , 1442.533  , ..., 1295.08753, 1215.44897,
#        1107.11488])
